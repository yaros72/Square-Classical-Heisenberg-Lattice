# %%
from MC_CG import SquareClassicalHeisenbergLattice
# %matplotlib inline

# %%
SCHL=SquareClassicalHeisenbergLattice(L=16,J=1,K=-0.25,D=0.4,B=0)

# %%
SCHL.ground_state(niter=20)
# Out:
# 100% |########################################################################|

# %%
SCHL.plot_lattice()

# %%
SCHL.plot_fourier()

# %%
SCHL.detect_phase()
# Out:
# 'antiferromagnet'

# %%
SCHL.E
# Out:
# -2.223303606987752

# %%
SCHL.detect_skyrmion()
# Out:
# -0.00023162862671555952
