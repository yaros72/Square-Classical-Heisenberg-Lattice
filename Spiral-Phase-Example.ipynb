# %% [markdown]
# ## Hamiltonian parameters:
#
# size=32 J=-1 K=0.1 B=1 D=1

# %%
from Square_Skyrmion_Annealing import Square_Skyrmion_Annealing
SSA=Square_Skyrmion_Annealing(size=32,J=-1,K=0.1,B=1,D=1)

# %% [markdown]
# ## Anneal system:
# ./Square_Skyrmion_Annealing create magnetization.dat file
#
# Calculation take about 2 minutes on Macbook Pro late 2011

# %%
SSA.solve()

# %% [markdown]
# ## Collect results:
# Square_Skyrmion_Annealing object collect information from magnetization.dat file

# %%
SSA.results()

# %% [markdown]
# ## Plot results configuration:

# %%
SSA.plot_lattice_real()

# %%
SSA.plot_lattice_staggered()

# %%
SSA.plot_lattice_fft_real()
